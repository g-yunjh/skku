# %% [markdown]
# # 1. why 파이썬? 가장 인기 있는 이유2?

# %% [markdown]
# ## a. 판다스는? 🐼
# ---
# - **데이터 프레임(DataFrame)을 사용해서, 데이터를 시각화, 분석할 수 있는 패키지** = R 대부분 기능과 유사
# - 판다 X = 계량 경제학에서 사용하는 패널 데이터(PANner DAta) = 종단 + 횡단 데이터 = 가로세로 의미가 있는 데이터셋 처리
# - 데이터를 다루기 위한 **시리즈(Series) 클래스와 데이터프레임(DataFrame) 클래스** = 데이터 사이언스에 필수 패키지
# - 판다스는 느리다 X --> 넘파이에 비해서 느리다 = 넘파이 기반<br><br>
#
# - <span style="background:yellow; color:red">**넘파이와 판다스 차이? = 넘파이 <-- 리스트 but 판다스 <-- 딕셔너리**</span>

# %% [markdown]
# ## b. 일단 해보자. 선언! 📢
# ---

# %%
# !pip install pandas
import numpy as np
import pandas as pd
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## c. 시리즈 만들기 🛤️
# ---
# - 판다스 시리즈 = 넘파이 1차원 어레이 = 넘파이 1차원 시리즈 = 벡터와 같은 개념
# - but, 판다스 시리즈 = 인덱스(index) + 값(value)

# %%
ps = pd.Series([90, 95, 80, 87, 85]) # 인덱스 X --> 자동정수 채우기
ps
# Out:
# 0    90
# 1    95
# 2    80
# 3    87
# 4    85
# dtype: int64

# %% [markdown]
# - 넘파이랑 비슷한데?

# %%
a1 = np.array([90, 95, 80, 87, 85]) # 넘파이 시리즈와 비교해보면?
a1
# Out:
# array([90, 95, 80, 87, 85])

# %% [markdown]
# - 차원도 비슷할 듯...

# %%
ps.shape, a1.shape # 차원을 보자~
# Out:
# ((5,), (5,))

# %% [markdown]
# - 당연히 넘피아 기반으로 만들어 졌으니깐 당연히 넘피아 기반으로 만들어 졌으니깐

# %%
ps = pd.Series(range(3, 7)) # range도 가능
ps
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %% [markdown]
# - 하지만, 판다스는 넘파이에 종단, 횡단 인덱스에 라벨 = 이름을 가지고 있어요.

# %%
ps = pd.Series([90, 95, 80, 87, 85], index=['a', 'b', 'c', 'd', 'e']) # 인덱스 라벨
ps
# Out:
# a    90
# b    95
# c    80
# d    87
# e    85
# dtype: int64

# %%
ps.index # 인덱스 보기
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
ps.values # 벨류 보기
# Out:
# array([90, 95, 80, 87, 85])

# %%
ps.index.name = 'students' # 컬럼이 존재X = 궅이 이름 붙이자면... 
ps.name = 'math' # 컬럼이 존재X = 시리즈에 이름 붙이자면...
ps
# Out:
# students
# a    90
# b    95
# c    80
# d    87
# e    85
# Name: math, dtype: int64

# %% [markdown]
# - 딕셔너리로 지정 가능 = 비교 넘파이는 리스트
# - 혹시나... 딕셔너리가 뭔가요?
# - 참고하세요:  https://dojang.io/mod/page/view.php?id=2213

# %% [markdown]
# - <span style="background:yellow; color:red">**판다스 시리즈에서는 키 = 인덱스 라벨**</span>

# %%
dc = {'math': [90, 95, 80, 87, 85]} # 그런데 시리즈는 1차원 = 인덱스 라벨만! = 즉 인덱스 기준 <-- 주의!!
pd.Series(dc)
# Out:
# math    [90, 95, 80, 87, 85]
# dtype: object

# %%
dc = {'a': 90, 'b': 95, 'c': 80, 'd': 87, 'e': 85} # 수정 방법1
pd.Series(dc, name='math')
# Out:
# a    90
# b    95
# c    80
# d    87
# e    85
# Name: math, dtype: int64

# %%
dc = {'math': [90, 95, 80, 87, 85]} # 수정 방법2
pd.DataFrame(dc)
# Out:
#    math
# 0    90
# 1    95
# 2    80
# 3    87
# 4    85

# %% [markdown]
# ## d. 시리즈 인덱싱과 슬라이싱 📇
# ---
# - 시리즈는 기본적으로 넘파이에서 가능한 인덱싱과 슬라이싱 + 인덱스 이름(라벨)을 기반한 인덱싱과 슬라이싱

# %%
ps
# Out:
# students
# a    90
# b    95
# c    80
# d    87
# e    85
# Name: math, dtype: int64

# %% [markdown]
# - 이제껏 여기저기 기능들이 합쳐저서... 중복된 기능들 --> deprecated = 원래 데이터프레임에서도 되었지만... deprecated

# %%
ps[0], ps[1], ps[-1] # 곧 없어지는 방법
# Out:
# C:\Users\tysep16\AppData\Local\Temp\ipykernel_17096\198178904.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ps[0], ps[1], ps[-1] # 곧 없어지는 방법
# (np.int64(90), np.int64(95), np.int64(85))

# %% [markdown]
# - <span style='background: yellow; color: red'>**다시 강조, 판다시 시리즈에서는 키값 =  인덱스 라벨 = 행(row)**</span>

# %%
ps['a'], ps['e'] # 당연 인덱스를 이용한 방법
# Out:
# (np.int64(90), np.int64(85))

# %%
ps[['a', 'c', 'e']] # 넘파이 기반이니 [[]] 가능하겠죠?
# Out:
# students
# a    90
# c    80
# e    85
# Name: math, dtype: int64

# %% [markdown]
# - 그렇다면 불리언 인덱싱도 가능하단 이야기...

# %%
ps > 85 # 불리언 시리즈
# Out:
# students
# a     True
# b     True
# c    False
# d     True
# e    False
# Name: math, dtype: bool

# %%
ps[ps > 85]
# Out:
# students
# a    90
# b    95
# d    87
# Name: math, dtype: int64

# %%
ps[(ps > 85) & (ps < 95)] # () AND ()
# Out:
# students
# a    90
# d    87
# Name: math, dtype: int64

# %% [markdown]
# - 판다스 만의 특이한 접근 법 = ps.인덱스 값 = 리스트 < 넘파이 < 판다스
# - 주의: <span style='background: yellow; color: red'>**다시 또 강조, 판다스 시리즈 키값 = 인덱스 라벨 = 행(row)**</span>

# %%
ps
# Out:
# students
# a    90
# b    95
# c    80
# d    87
# e    85
# Name: math, dtype: int64

# %%
ps.a, ps.d, ps.e
# Out:
# (np.int64(90), np.int64(87), np.int64(85))

# %% [markdown]
# - 이건 당연 = 판다스 시리즈에서는 컬럼이 없으므로...

# %%
ps.math # 시리즈에서는 키는 인덱스 라벨라고 가정했으니... 에러
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[437], line 1
# ----> 1 ps.math # 시리즈에서는 키는 인덱스 라벨라고 가정했으니... 에러
#
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'math'

# %% [markdown]
# - 당연, 슬라이싱 가능

# %%
ps['a':'c'] # a부터 c까지 = 주의 c 포함임!!
# Out:
# students
# a    90
# b    95
# c    80
# Name: math, dtype: int64

# %%
ps[:'d'] # 처음부터 d까지 = 주의 d 포함임!!
# Out:
# students
# a    90
# b    95
# c    80
# d    87
# Name: math, dtype: int64

# %% [markdown]
# - 판다스 시리즈 객체는 인덱스 라벨으로 인덱싱 = 시리즈 값은 value로 접근 가능

# %%
'b' in ps # 인덱스 라벨에 b라는 학생이 있는가?
# Out:
# True

# %%
[f for f in ps] # ps value를 콜한 것
# Out:
# [90, 95, 80, 87, 85]

# %% [markdown]
# - 헷갈리네... 판다스...
# - 그래서 이럴 땐... FM이 정석 like 넘파이

# %%
ps
# Out:
# students
# a    90
# b    95
# c    80
# d    87
# e    85
# Name: math, dtype: int64

# %%
[f for f in ps.index] # 인덱스 가져오기
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
[f for f in ps.values] # 이래야 인덱스 값을 본 것
# Out:
# [np.int64(90), np.int64(95), np.int64(80), np.int64(87), np.int64(85)]

# %% [markdown]
# ## e. 데이터프레임 만들기 🛤️
# ---
# - 판다스 데이터프레임 = 넘파이 2차원 어레이 = 매트릭스와 같은 개념 <-- 딕셔너리
# - but, 판다스 시리즈 = 인덱스(index)/컬럼(column) + 값(value)

# %%
dc = {'math': [65,95,65,55,80], 'eng': [55,100,90,80,30], 'sci': [50,50,60,75,30], 'com': [40,80,30,80,100]}
df = pd.DataFrame(dc)
df
# Out:
#    math  eng  sci  com
# 0    65   55   50   40
# 1    95  100   50   80
# 2    65   90   60   30
# 3    55   80   75   80
# 4    80   30   30  100

# %% [markdown]
# - 인덱스 디폴트 = 0부터 시작하는 정수, 인덱스를 직접 지정 가능

# %%
df = pd.DataFrame(dc, index=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#    math  eng  sci  com
# a    65   55   50   40
# b    95  100   50   80
# c    65   90   60   30
# d    55   80   75   80
# e    80   30   30  100

# %%
df.index # 인덱스 라벨 보기
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.columns # 컬럼 라벨 보기
# Out:
# Index(['math', 'eng', 'sci', 'com'], dtype='object')

# %% [markdown]
# - 인덱스/컬럼 라벨 변경도 가능

# %%
df.index = ['a', 'b', 'c', 'd', 'f']
df
# Out:
#    math  eng  sci  com
# a    65   55   50   40
# b    95  100   50   80
# c    65   90   60   30
# d    55   80   75   80
# f    80   30   30  100

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'f'], dtype='object')

# %%
df.columns = ['math', 'eng', 'sci', 'kor']
df
# Out:
#    math  eng  sci  kor
# a    65   55   50   40
# b    95  100   50   80
# c    65   90   60   30
# d    55   80   75   80
# f    80   30   30  100

# %%
df.columns
# Out:
# Index(['math', 'eng', 'sci', 'kor'], dtype='object')

# %%
df.values # 데이터프레임 값보기
# Out:
# array([[ 65,  55,  50,  40],
#        [ 95, 100,  50,  80],
#        [ 65,  90,  60,  30],
#        [ 55,  80,  75,  80],
#        [ 80,  30,  30, 100]])

# %% [markdown]
# - 인덱스, 컬럼 이름을 붙이는 것도 가능

# %%
df.index.name = 'students'
df
# Out:
#           math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %%
df.columns.name = 'mid_term'
df
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %%
df.T # 트랜스포즈 = 대각화
# Out:
# students   a    b   c   d    f
# mid_term
# math      65   95  65  55   80
# eng       55  100  90  80   30
# sci       50   50  60  75   30
# kor       40   80  30  80  100

# %% [markdown]
# ## f. 데이터프레임 인덱싱과 슬라이싱 feat. **열방향** 📇
# ---
# - 열 인덱싱 = 열 라벨(column label)을 키값으로 인덱싱

# %%
df
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %% [markdown]
# - <span style='background: yellow; color: red'>**데이터프레임에서는 키값 = 컬럼 라벨**</span>

# %%
df['math']
# Out:
# students
# a    65
# b    95
# c    65
# d    55
# f    80
# Name: math, dtype: int64

# %% [markdown]
# - !!!출력물의 클래스 타입 중요 = 차원 중요!!!

# %%
df['sci'] # 판다스 시리즈로 반환
# Out:
# students
# a    50
# b    50
# c    60
# d    75
# f    30
# Name: sci, dtype: int64

# %%
df[['sci']] # 판다스 데이터프레임로 반환
# Out:
# mid_term  sci
# students
# a          50
# b          50
# c          60
# d          75
# f          30

# %%
df[['math', 'eng']] # 넘파이 기반이니 [[]] 가능하겠죠?
# Out:
# mid_term  math  eng
# students
# a           65   55
# b           95  100
# c           65   90
# d           55   80
# f           80   30

# %% [markdown]
# - 리스트 형태로 접근 가능 --> 불리언 인덱싱 고고고

# %%
df['math'] > 70
# Out:
# students
# a    False
# b     True
# c    False
# d    False
# f     True
# Name: math, dtype: bool

# %% [markdown]
# - <span style='background: yellow; color: red'>**불리언 인덱싱으로 열의 값을 기준으로 행들을 선택한 것!!**</span>

# %%
df[df['math'] > 70] # 행이 선택된 것 = 중요!
# Out:
# mid_term  math  eng  sci  kor
# students
# b           95  100   50   80
# f           80   30   30  100

# %%
df[df['math'] > 70]['math'] # 아! 데이터프레임(2차)였지 --> 시리즈(1차)
# Out:
# students
# b    95
# f    80
# Name: math, dtype: int64

# %% [markdown]
# - <span style='background: yellow; color: red'>**데이터프레임의 강력한 인덱싱 = 키값 = 컬럼 라벨이 있으니 가능한 방법**</span>
# - **단, 컬럼 라벨이 영문만 가능 + 띄어쓰기X + 특수문자X**

# %%
df.math
# Out:
# students
# a    65
# b    95
# c    65
# d    55
# f    80
# Name: math, dtype: int64

# %%
df.eng
# Out:
# students
# a     55
# b    100
# c     90
# d     80
# f     30
# Name: eng, dtype: int64

# %% [markdown]
# - 특이하게, 컬럼 라벨로 슬라이싱은 불가... = 헷갈려지기 시작함

# %%
df['math':'sci']
# Out:
# Empty DataFrame
# Columns: [math, eng, sci, kor]
# Index: []

# %% [markdown]
# - 넘파이 행렬식으로 인덱싱도 안돼요! = 앞에서 시리즈일때도 넘파이식 인덱싱이 deprecated...

# %%
df[:, 'math'] # 넘파이 행렬식으론 안돼요~
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), 'math')
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[468], line 1
# ...

# %%
df[:, 2] # 당연히 숫자 인덱싱도 불가

# %% [markdown]
# ## g. 데이터프레임 인덱싱과 슬라이싱 feat. **행방향** 📇
# ---
# - <span style='background: yellow; color: red'>**행 인덱싱 = 인덱스 라벨(index label)을 키값으로 슬라이싱만...**</span>

# %%
df
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %%
df['a'] # 행 인덱싱 = 인덱스 라벨로는 인덱싱이 불가
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[470], line 1
# ----> 1 df['a'] # 행 인덱싱 = 인덱스 라벨로는 인덱싱이 불가
#
# ...

# %%
df['a':'b'] # 근데 행 인덱스로 슬라이싱은 가능 --> 열괴 반대

# %%
df[2] # 정수 인덱싱도 불가
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[471], line 1
# ----> 1 df[2] # 정수 인덱싱도 불가
#
# ...

# %%
df[:2] # 그런데? 정수 슬라이싱은 또 가능.

# %%
df[::2] # 스트라이딩도 가능하네..
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %% [markdown]
# - 다시 복습, 열방향으로 불리언 --> 행방향 인덱싱

# %%
df.math < 70
# Out:
# students
# a     True
# b    False
# c     True
# d     True
# f    False
# Name: math, dtype: bool

# %%
df[df.math < 70]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %% [markdown]
# - 당연히 불리언 인덱싱 가능

# %%
df[[True, False, True, True, False]]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %% [markdown]
# ## h. 그래서, <span style='font-size: 200%; background: lime'>**아묻따! iloc**</span> 🚨
# ---
# - 데이터프레임 열 & 행 순서를 나타내는 정수(integer)를 사용해서 열방향 & 행방향 인덱싱과 슬라이싱 = 넘파이에서 되는 것 다

# %% [markdown]
# - 먼저 열방향 = 넘파이에서 되는 것 모두 다

# %%
df.iloc[:, 0] # 그래서! iloc! integer 넘버는 가능
# Out:
# students
# a    65
# b    95
# c    65
# d    55
# f    80
# Name: math, dtype: int64

# %%
df.iloc[:, 0:3] # 슬라이싱도 가능하고
# Out:
# mid_term  math  eng  sci
# students
# a           65   55   50
# b           95  100   50
# c           65   90   60
# d           55   80   75
# f           80   30   30

# %%
df.iloc[:, -1] # 뒤에서부터도 가능하고
# Out:
# students
# a     40
# b     80
# c     30
# d     80
# f    100
# Name: kor, dtype: int64

# %% [markdown]
# - 리스트 속 리스트도 가능

# %%
df.iloc[:, [0, 3]]
# Out:
# mid_term  math  kor
# students
# a           65   40
# b           95   80
# c           65   30
# d           55   80
# f           80  100

# %%
df.iloc[:, [True, False, True, True]]
# Out:
# mid_term  math  sci  kor
# students
# a           65   50   40
# b           95   50   80
# c           65   60   30
# d           55   75   80
# f           80   30  100

# %% [markdown]
# ---
# # 잠깐! 컴프리헨션(comprehension) = 파이썬 문법, 이제 배워보자.

# %% [markdown]
# - 컴프리헨션(comprehension) = 파이썬 효율적 + 간결한 문법 = 실행문 + 반복문 + 조건문 형태
# - 참조하세요.: https://wikidocs.net/138204

# %%
df
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %% [markdown]
# - 실행문 + 반복문 = 반복문의 인자를 하나하나 뺴서 실행문에 넣는다는 개념

# %%
[a + 10 for a in df.eng] # 시리즈 value에 상수 더하기
# Out:
# [65, 110, 100, 90, 40]

# %%
[f < 70 for f in df['kor']] # 시리즈에 조건문 넣기
# Out:
# [True, False, True, False, False]

# %%
df[[f < 70 for f in df['kor']]] # 불리언 인덱싱으로 데이터프레임 출력
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30

# %%
df[df.kor < 70] # 같은 것
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30

# %% [markdown]
# ---

# %% [markdown]
# - 다시 iloc으로 돌아와서 컴프리헨션을 적용해 보자

# %%
df.iloc[:, [ 'a' in f for f in df.columns]] # 이건 열 선택, 컬럼에 'a'가 있는 컬럼만 선택
# Out:
# mid_term  math
# students
# a           65
# b           95
# c           65
# d           55
# f           80

# %% [markdown]
# - 스트라이딩도 가능

# %%
df.iloc[:, 0:3:2]
# Out:
# mid_term  math  sci
# students
# a           65   50
# b           95   50
# c           65   60
# d           55   75
# f           80   30

# %% [markdown]
# - 당연 range도 사용가능

# %%
df.iloc[:, range(2)]
# Out:
# mid_term  math  eng
# students
# a           65   55
# b           95  100
# c           65   90
# d           55   80
# f           80   30

# %% [markdown]
# - 행 방향은? = 넘파이에서 되는 것 다

# %%
df.iloc[0, :]
# Out:
# mid_term
# math    65
# eng     55
# sci     50
# kor     40
# Name: a, dtype: int64

# %%
df.iloc[0]
# Out:
# mid_term
# math    65
# eng     55
# sci     50
# kor     40
# Name: a, dtype: int64

# %%
df.iloc[[1, 3], :]
# Out:
# mid_term  math  eng  sci  kor
# students
# b           95  100   50   80
# d           55   80   75   80

# %%
df.iloc[[1, 3]]
# Out:
# mid_term  math  eng  sci  kor
# students
# b           95  100   50   80
# d           55   80   75   80

# %%
df.iloc[[True, False, True, False, True], :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %%
df.iloc[[True, False, True, False, True]]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %%
[f < 70 for f in df['kor']] # 다시한번 강조 --> 이번이 3번째... 그만큼 중요
# Out:
# [True, False, True, False, False]

# %%
df.iloc[[f < 70 for f in df['kor']], :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30

# %%
df.iloc[[f < 70 for f in df['kor']]] # 같은 것
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30

# %%
df.iloc[df.kor < 70] # --> 이게 왜? 불리언 인덱싱 되면서? 오락가락...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[498], line 1
# ----> 1 df.iloc[df.kor < 70] # --> 이게 왜? 불리언 인덱싱 되면서? 오락가락...
#
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\drive_t\aLEC\2025\강의자료\25_1_DV\.lec\Lib\site-packages\pandas\core\indexing.py:1738, in _iLocIndexer._getitem_axis(self, key, axis)
#    1735     key = np.asarray(key)
#    1737 if com.is_bool_indexer(key):
# -> 1738     self._validate_key(key, axis)
#    1739     return self._getbool_axis(key, axis=axis)
#    1741 # a list of integers
#
# ...

# %%
df[df.kor < 70] # 이건 되면서
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30

# %%
df.iloc[range(2), :] # 물론 range 됩니다.
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80

# %%
df.iloc[range(2)]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80

# %% [markdown]
# ## i. 또한, <span style='font-size: 200%; background: pink'>**아묻따!아묻따! loc**</span> 🚨
# ---
# - 데이터프레임 열 & 행 순서를 나타내는 라벨을 사용해서 열방향 & 행방향 인덱싱과 슬라이싱

# %% [markdown]
# - 먼저 열방향

# %%
df
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %% [markdown]
# - 결국, iloc이 가능한 것들 다 가능, integer --> 라벨

# %%
df.loc[:, 'eng']
# Out:
# students
# a     55
# b    100
# c     90
# d     80
# f     30
# Name: eng, dtype: int64

# %%
df.loc[:, 'math':'sci'] # 슬라이싱 가능
# Out:
# mid_term  math  eng  sci
# students
# a           65   55   50
# b           95  100   50
# c           65   90   60
# d           55   80   75
# f           80   30   30

# %%
df.loc[:, 'math'::2] # 스트라이딩도 가능
# Out:
# mid_term  math  sci
# students
# a           65   50
# b           95   50
# c           65   60
# d           55   75
# f           80   30

# %%
df.loc[:, ['eng', 'sci']] # 리스트를 이용한 복수 선택도 가능
# Out:
# mid_term  eng  sci
# students
# a          55   50
# b         100   50
# c          90   60
# d          80   75
# f          30   30

# %%
df.loc[:, [True, False, True, False]] # 당연히 불리언 인덱싱도 가능
# Out:
# mid_term  math  sci
# students
# a           65   50
# b           95   50
# c           65   60
# d           55   75
# f           80   30

# %%
df.loc[:, ['a' in cn or 's' in cn for cn in df.columns]] # 그래서 컨프리헨션도 가능!
# Out:
# mid_term  math  sci
# students
# a           65   50
# b           95   50
# c           65   60
# d           55   75
# f           80   30

# %% [markdown]
# - 다음 행방향

# %%
df.loc['a', :]
# Out:
# mid_term
# math    65
# eng     55
# sci     50
# kor     40
# Name: a, dtype: int64

# %%
df.loc['a']
# Out:
# mid_term
# math    65
# eng     55
# sci     50
# kor     40
# Name: a, dtype: int64

# %%
df.loc[['a', 'c', 'f'], :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %%
df.loc[['a', 'c', 'f']] # 물론 생략가능
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %%
df.loc['a':'c'] # 슬라이싱 가능
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30

# %%
df.loc['a'::2] # 스트라이딩 가능
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# f           80   30   30  100

# %% [markdown]
# - 컴프리헨션은 너무 많이 했으니...

# %%
df.loc[df.math < 70, :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %%
df.loc[df.math < 70]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %%
df.loc[[f < 70 for f in df.math], :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %%
df.loc[[f < 70 for f in df.math]]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %% [markdown]
# ## j. 요약 🔛
# ---
# - 판다스 시리즈에서 키는 인덱스
# - 판다스 데이터프레임에서 키는 컬럼
#
# - df['문자'] = df.'문자' = 컬럼선택 but 슬라이딩 안됨
# - df['문자':'문자'] = 로우선택 but 단일문자 인덱싱 안됨
#
# - 불리언인덱싱은 로우컬럼 다가능 = 컨프리헨션
#
# - 로우선택시 .iloc[] = .iloc[, :] --> 후자 추천
# - 로우선택시 .loc[] = .loc[, :] --> 후자 추천
#
# - <span style='background:yellow; color:red'>**열 --> columns**</span>
#
# |     type of indexer      |  .  |  []  |  .iloc  |   .loc   | 추천 |
# |:-------------------------|:---:|:----:|:-------:|:--------:|:-------:|
# |           int            |  X  |  X   |    O    |    X     | iloc 쓰세요 |
# |         int:int          |  X  |  X   |    O    |    X     | iloc 쓰세요 |
# |        [int,int]         |  X  |  X   |    O    |    X     | iloc 쓰세요 |
# |           str            |  O  |  O   |    X    |    O     | . 혹은 [] 혹은 loc |
# |         str:str          |  X  |  X   |    X    |    O     | loc 쓰세요 |
# |        [str,str]         |  X  |  O   |    X    |    O     | loc 쓰세요 |
# |       [bool,bool]        |  X  |  X   |    O    |    O     | loc 쓰세요 |
#
# - <span style='background:yellow; color:red'>**행 --> rows**</span>
#
# |     type of indexer      |  .  |  []  |  .iloc  |   .loc   | 내가 쓴다면? |
# |:-------------------------|:---:|:----:|:-------:|:--------:|:-------:|
# |           int            |  X  |  X   |    O    |    X     | iloc 쓰세요 |
# |         int:int          |  X  |  O   |    O    |    X     | iloc 쓰세요 |
# |        [int,int]         |  X  |  X   |    O    |    X     | iloc 쓰세요 |
# |           str            |  X  |  X   |    X    |    O     | loc 쓰세요  |
# |         str:str          |  X  |  O   |    X    |    O     | loc 쓰세요  |
# |        [str,str]         |  X  |  X   |    X    |    O     | loc 쓰세요  |
# |       [bool,bool]        |  X  |  O   |    O    |    O     | loc 쓰세요  |

# %% [markdown]
# ## l. 그냥 이거 쓰세요. 🤩
# ---
# - 가장 추천 --> 가장 안전 but 타자 많음

# %%
df.loc[:, :]
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# b           95  100   50   80
# c           65   90   60   30
# d           55   80   75   80
# f           80   30   30  100

# %% [markdown]
# - 특별한 상황 1. and 2. = 열을 뽑을 때

# %%
df.math # 특별예외 1
# Out:
# students
# a    65
# b    95
# c    65
# d    55
# f    80
# Name: math, dtype: int64

# %%
df['math'] # 특별예외 2
# Out:
# students
# a    65
# b    95
# c    65
# d    55
# f    80
# Name: math, dtype: int64

# %% [markdown]
# ### - 특별한 상황 3. = 행을 뽑을 때

# %%
df[df.math < 70] # 특정 열을 기준으로 조건을 만족시키는 행을 뽑을 때... 특별예외 3
# Out:
# mid_term  math  eng  sci  kor
# students
# a           65   55   50   40
# c           65   90   60   30
# d           55   80   75   80

# %% [markdown]
# # 2. 인생은 실전이야.

# %% [markdown]
# ## a. 준비 = 파일 읽어오기 👌
# ---
# - url에서 직접 받아오기

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tysep16/DV25_1/refs/heads/main/movie.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# - (터미널로 다운받아서...) 파일에서 불러오기

# %%
df = pd.read_csv('./data/movie.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# - 인덱스/컬럼 라벨 출력

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# - 상위 10개만 출력, 하위 10개만 출력

# %%
df.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
df.tail(10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4906  Color     Shane Carruth                   143.0      77.0
# 4907  Color  Neill Dela Llana                    35.0      80.0
# 4908  Color  Robert Rodriguez                    56.0      81.0
# 4909  Color   Anthony Vallone                     NaN      84.0
# 4910  Color      Edward Burns                    14.0      95.0
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4906                    291.0                     8.0      David Sullivan
# 4907                      0.0                     0.0     Edgar Tancangco
# ...

# %% [markdown]
# - 옵션 변경 --> 꼼수

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
pd.options.display.min_rows = 30
df
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 0               Color       James Cameron                   723.0     178.0
# 1               Color      Gore Verbinski                   302.0     169.0
# 2               Color          Sam Mendes                   602.0     148.0
# 3               Color   Christopher Nolan                   813.0     164.0
# 4                 NaN         Doug Walker                     NaN       NaN
# 5               Color      Andrew Stanton                   462.0     132.0
# 6               Color           Sam Raimi                   392.0     156.0
# 7               Color        Nathan Greno                   324.0     100.0
# 8               Color         Joss Whedon                   635.0     141.0
# 9               Color         David Yates                   375.0     153.0
# 10              Color         Zack Snyder                   673.0     183.0
# ...

# %%
df.T
# Out:
#                                                                         0     \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                 723.0
# duration                                                               178.0
# director_facebook_likes                                                  0.0
# actor_3_facebook_likes                                                 855.0
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                1000.0
# gross                                                            760505847.0
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
pd.options.display.min_rows = 10
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.director_name # 감독 이름만 출력
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
df[['genres', 'movie_title', 'imdb_score', 'movie_facebook_likes']] # 원하는 컬럼 모아서 출력
# Out:
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 4911                     Comedy|Drama
# 4912     Crime|Drama|Mystery|Thriller
# 4913            Drama|Horror|Thriller
# 4914             Comedy|Drama|Romance
# 4915                      Documentary
#
#                                      movie_title  imdb_score  \
# 0                                         Avatar         7.9
# 1       Pirates of the Caribbean: At World's End         7.1
# 2                                        Spectre         6.8
# 3                          The Dark Knight Rises         8.5
# 4     Star Wars: Episode VII - The Force Awakens         7.1
# ...                                          ...         ...
# 4911                     Signed Sealed Delivered         7.7
# ...

# %%
df[['movie_title', 'genres', 'movie_facebook_likes', 'imdb_score']] # 순서도 정할 수 있음 = 방법 1
# Out:
#                                      movie_title  \
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens
# ...                                          ...
# 4911                     Signed Sealed Delivered
# 4912                               The Following
# 4913                        A Plague So Pleasant
# 4914                            Shanghai Calling
# 4915                           My Date with Drew
#
#                                genres  movie_facebook_likes  imdb_score
# 0     Action|Adventure|Fantasy|Sci-Fi                 33000         7.9
# 1            Action|Adventure|Fantasy                     0         7.1
# 2           Action|Adventure|Thriller                 85000         6.8
# 3                     Action|Thriller                164000         8.5
# ...

# %%
df.loc[:, ['movie_title', 'genres', 'movie_facebook_likes', 'imdb_score']] # 순서도 정할 수 있음
# Out:
#                                      movie_title  \
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens
# ...                                          ...
# 4911                     Signed Sealed Delivered
# 4912                               The Following
# 4913                        A Plague So Pleasant
# 4914                            Shanghai Calling
# 4915                           My Date with Drew
#
#                                genres  movie_facebook_likes  imdb_score
# 0     Action|Adventure|Fantasy|Sci-Fi                 33000         7.9
# 1            Action|Adventure|Fantasy                     0         7.1
# 2           Action|Adventure|Thriller                 85000         6.8
# 3                     Action|Thriller                164000         8.5
# ...

# %%
df.loc[:, ['facebook' in f for f in df.columns]] # 컨프리헨션으로 원하는 열을 선택
# Out:
#       director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                         0.0                   855.0                  1000.0
# 1                       563.0                  1000.0                 40000.0
# 2                         0.0                   161.0                 11000.0
# 3                     22000.0                 23000.0                 27000.0
# 4                       131.0                     NaN                   131.0
# ...                       ...                     ...                     ...
# 4911                      2.0                   318.0                   637.0
# 4912                      NaN                   319.0                   841.0
# 4913                      0.0                     0.0                     0.0
# 4914                      0.0                   489.0                   946.0
# 4915                     16.0                    16.0                    86.0
#
# ...

# %%
df.loc[df.imdb_score > 9.0, :]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 2725                      0.0                   176.0    Andrea Martin
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 3402                      0.0                  3000.0    Marlon Brando
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...

# %%
df.loc[df.imdb_score > 9.0]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 2725                      0.0                   176.0    Andrea Martin
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 3402                      0.0                  3000.0    Marlon Brando
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...

# %%
df[df.imdb_score > 9.0]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 2725                      0.0                   176.0    Andrea Martin
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 3402                      0.0                  3000.0    Marlon Brando
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...

# %%
df.loc[[f > 9 for f in df.imdb_score], :]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 2725                      0.0                   176.0    Andrea Martin
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 3402                      0.0                  3000.0    Marlon Brando
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...

# %%
df.loc[[f > 9 for f in df.imdb_score]]
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1920  Color        Frank Darabont                   199.0     142.0
# 2725  Color        John Blanchard                     NaN      65.0
# 2779  Color                   NaN                    53.0      55.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 2725                      0.0                   176.0    Andrea Martin
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 3402                      0.0                  3000.0    Marlon Brando
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...

# %%
df.iloc[:100:5]
# Out:
#     color    director_name  num_critic_for_reviews  duration  \
# 0   Color    James Cameron                   723.0     178.0
# 5   Color   Andrew Stanton                   462.0     132.0
# 10  Color      Zack Snyder                   673.0     183.0
# 15  Color      Zack Snyder                   733.0     143.0
# 20  Color    Peter Jackson                   422.0     164.0
# 25  Color    Peter Jackson                   446.0     201.0
# 30  Color       Sam Mendes                   750.0     143.0
# 35  Color      Dan Scanlon                   376.0     104.0
# 40  Color  Joseph Kosinski                   469.0     125.0
# 45  Color        James Wan                   424.0     140.0
# 50  Color     Baz Luhrmann                   490.0     143.0
# 55  Color       Peter Sohn                   298.0      93.0
# 60  Color  Roland Emmerich                   367.0     158.0
# 65  Color     Bryan Singer                   396.0     144.0
# ...

# %% [markdown]
# # 3. 3주차 과제

# %% [markdown]
# ## a. 다음 지시대로 빈 코드셀을 작성-->실행하여 캡처화면(jpg, png...)을 제출하세요. 😊
# ---
# 1. 다음 url에서 csv 파일을 읽어와 df라는 이름의 데이터프레임으로 만들어 보세요.(url = 'https://raw.githubusercontent.com/tysep16/DV25_1/refs/heads/main/movie.csv')
# - *힌트: pd.read_csv()*

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tysep16/DV25_1/refs/heads/main/movie.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# 2. df의 컬럼 라벨(열 라벨)을 출력해 보세요.
# - *힌트: df.columns*

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# 3. 컨프리헨션을 이용하여 컬럼 라벨에 actor가 들어간 컬럼만 출력해 보세요.
# - *힌트: df.?[?, ['?' in ? for ? in ?]*

# %%
df.loc[:, ['actor' in a for a in df.columns]]
# Out:
#       actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                      855.0  Joel David Moore                  1000.0
# 1                     1000.0     Orlando Bloom                 40000.0
# 2                      161.0      Rory Kinnear                 11000.0
# 3                    23000.0    Christian Bale                 27000.0
# 4                        NaN        Rob Walker                   131.0
# ...                      ...               ...                     ...
# 4911                   318.0     Daphne Zuniga                   637.0
# 4912                   319.0     Valorie Curry                   841.0
# 4913                     0.0     Maxwell Moody                     0.0
# 4914                   489.0     Daniel Henney                   946.0
# 4915                    16.0  Brian Herzlinger                    86.0
#
#          actor_1_name          actor_3_name  actor_2_facebook_likes
# ...

# %% [markdown]
# 4. 감독 중 'James Cameron'이 감독한 영화의 행(row)만 출력해 보세요. (컨프리헨션을 써도 ok, 인덱싱 문법을 써도 ok)
# - *힌트: df.?[[이름 == ? for ? in ?], :] 혹은 df[df.? == 이름]*

# %%
df.loc[['James Cameron' == a for a in df.director_name], :]
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 285   Color  James Cameron                   210.0     153.0
# 288   Color  James Cameron                    94.0     141.0
# 599   Color  James Cameron                    82.0     171.0
# 2455  Color  James Cameron                   250.0     154.0
# 3508  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 285                       0.0                   539.0  Jenette Goldstein
# 288                       0.0                   618.0        Tia Carrere
# 599                       0.0                   638.0         Todd Graff
# ...

# %%
df[df.director_name == 'James Cameron']
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 285   Color  James Cameron                   210.0     153.0
# 288   Color  James Cameron                    94.0     141.0
# 599   Color  James Cameron                    82.0     171.0
# 2455  Color  James Cameron                   250.0     154.0
# 3508  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 285                       0.0                   539.0  Jenette Goldstein
# 288                       0.0                   618.0        Tia Carrere
# 599                       0.0                   638.0         Todd Graff
# ...
